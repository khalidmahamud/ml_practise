# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
cols = ["area", "price"]
df = pd.read_csv("homeprices.data", names=cols)
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area, df.price, color="red", marker="+")
plt.xlabel("Area (sqr ft)")
plt.ylabel("Price (USD)")
# Out:
# Text(0, 0.5, 'Price (USD)')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]], df.price)
# Out:
# LinearRegression()

# %%
prediction_input = pd.DataFrame({"area": [3300]})
reg.predict(prediction_input)
# Out:
# array([628715.75342466])

# %%
d = pd.read_csv("predicted_data.csv", names=["area"])
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   9000
# 10  8600
# 11  7100

# %%
p = reg.predict(d)
d['price'] = p
d.to_csv("predicted_data.csv", index=False)

# %%
plt.scatter(df.area, df.price, color="red", marker="+")
plt.plot(df.area, reg.predict(df[["area"]]), color="blue")
plt.xlabel("Area (sqr ft)")
plt.ylabel("Price (USD)")
# Out:
# Text(0, 0.5, 'Price (USD)')
